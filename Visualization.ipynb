# %%
import pandas as pd
import numpy as np


df= pd.read_csv("D:/Project/traffic_recognition/Project/preprocesseddata.csv")
df

import seaborn as sns
sns.set_theme(style="darkgrid")
ax = sns.countplot(x="output", data=df)
