# %%
Preprocessing

# %%
import pandas as pd
import numpy as np


df= pd.read_csv("D:/Project/traffic_recognition/Project/extracted_features.csv")
df
# Out:
#         blob_doh   blob_log     canny  corner_fast  corner_foerstner  \
# 0      13.037037   7.938272  0.242529     0.145071          0.291504
# 1      12.370370   8.500000  0.248889     0.093734          0.286878
# 2      11.037037   9.666667  0.248889     0.119407          0.273713
# 3       5.703704   9.777778  0.244537     0.123291          0.258897
# 4      11.037037   9.444444  0.257292     0.118893          0.270780
# ...          ...        ...       ...          ...               ...
# 39204  19.518519  13.805556  0.154201     0.038554          0.201086
# 39205  23.203704  13.570370  0.127119     0.014590          0.155375
# 39206  20.500000  16.809524  0.152282     0.012170          0.148567
# 39207  23.000000  18.083333  0.137911     0.013268          0.136199
# 39208  21.155556  23.469136  0.121212     0.012771          0.145332
#
#        corner_harris  corner_kitchen_rosenfeld  corner_moravec  corner_peaks  \
# ...

# %%
#Checking Null Values

# %%
print(df.isnull().sum())
# Out:
# blob_doh                    17283
# blob_log                    16591
# canny                           0
# corner_fast                     0
# corner_foerstner                0
# corner_harris                   0
# corner_kitchen_rosenfeld        0
# corner_moravec                  0
# corner_peaks                    0
# corner_shi_tomasi               0
# greycomatrix                    0
# hessian_matrix                  0
# hessian_matrix_det              0
# hessian_matrix_eigvals          0
# local_binary_pattern            0
# peak_local_max                  0
# shape_index                  2315
# structure_tensor                0
# output                          0
# dtype: int64

# %%
#Removing 3 columns

# %%
del df['blob_doh']
del df['blob_log']
del df['shape_index']

# %%
df
# Out:
#           canny  corner_fast  corner_foerstner  corner_harris  \
# 0      0.242529     0.145071          0.291504       0.081133
# 1      0.248889     0.093734          0.286878       0.086278
# 2      0.248889     0.119407          0.273713       0.081399
# 3      0.244537     0.123291          0.258897       0.070438
# 4      0.257292     0.118893          0.270780       0.106749
# ...         ...          ...               ...            ...
# 39204  0.154201     0.038554          0.201086       0.007586
# 39205  0.127119     0.014590          0.155375      -0.040270
# 39206  0.152282     0.012170          0.148567      -0.051044
# 39207  0.137911     0.013268          0.136199      -0.059418
# 39208  0.121212     0.012771          0.145332      -0.039673
#
#        corner_kitchen_rosenfeld  corner_moravec  corner_peaks  \
# 0                      3.669575        0.099778     15.073529
# 1                      3.673270        0.112993     15.177778
# ...

# %%
#Printing the shape

# %%
df.shape
# Out:
# (39209, 16)

# %%
#Saving the file

# %%
df.to_csv('D:/Project/traffic_recognition/Project/preprocesseddata.csv', index=None)
